# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline

# %%
df = pd.read_csv("Training.csv")

# %%
df.info()
# There are no missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116322 entries, 0 to 116321
# Data columns (total 4 columns):
# Cycle     116322 non-null int64
# Type      116322 non-null int64
# Time      116322 non-null float64
# Values    116322 non-null float64
# dtypes: float64(2), int64(2)
# memory usage: 3.5 MB

# %%
df.corr()
# Out:
#            Cycle      Type      Time    Values
# Cycle   1.000000  0.378280 -0.002243 -0.269198
# Type    0.378280  1.000000  0.002917  0.147777
# Time   -0.002243  0.002917  1.000000 -0.701570
# Values -0.269198  0.147777 -0.701570  1.000000

# %%
df.head()
# Out:
#    Cycle  Type   Time  Values
# 0      2     2  101.0  20.402
# 1      2     2  102.0  20.402
# 2      2     2  103.0  20.402
# 3      2     2  104.0  20.402
# 4      2     2  105.0  20.402

# %%
sns.pairplot(df)
# Here, we can see relationship between 'Time' and 'EndTime' is a bit linear, 
# so Time is a reliable attribute to predict 'EndTime'
# We can also says there is no relation between 'Cycle' and 'Type' with 'EndTime'

# %%
sns.countplot(df["Cycle"])
# sns.countplot(df["Cycle"], hue=df["Type"])

# %%
sns.countplot(df["Type"])
# sns.countplot(df["Type"], hue=df["Cycle"])

# %%
sns.distplot(df["EndTime"], kde=True, rug=False)

# %%
# sns.jointplot(df['EndTime'], df['Time'])      # kind : { "scatter" | "reg" | "resid" | "kde" | "hex" }
sns.jointplot(df['EndTime'], df['Time'], kind="reg")

# %%
sns.distplot(df["Time"], kde=True, rug=False)

# %%
sns.boxplot(df['Values'])

# %%
sns.swarmplot(df["Type"], df['Cycle'])

# %%
sns.stripplot(df["Type"], df['Cycle'])

# %%
sns.jointplot(df['Time'], df['Values'])

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.metrics import mean_squared_error, r2_score
import seaborn as sns
import matplotlib.pyplot as plt


# define the data/predictors as the pre-set feature names
Training_data = "Training.csv"
Target_data = "Target.csv"
Testing_data = "Testing.csv"

columns = ["Cycle", "Type", "Time", "Values"]   # "Cycle", "Type", "Time", "Values"

Training_data = pd.read_csv(Training_data)
Target_data = pd.read_csv(Target_data)
Testing_data = pd.read_csv(Testing_data)


X = pd.DataFrame(data=Training_data, columns=columns)
print("\nTraining_data: \n\n", X.head())

# Put the target (housing value -- EndTime) in another DataFrame
Y = pd.DataFrame(data=Target_data, columns=["EndTime"])
print("\nTarget_data: \n\n", Y.head())

X_ = pd.DataFrame(data=Testing_data[:-99], columns=columns)
print("\nTesting_data: \n\n", X_.head())

lm = LinearRegression()
# lm = Lasso()
lm_model = lm.fit(X, Y)

predictions = lm.predict(X_)


print("\n",len(predictions))
print('\nCoefficient of determination: ', lm.score(X, Y))
print('\nSlope: ', lm_model.coef_)
print('\nIntercept: ', lm_model.intercept_)
print("\nPredictions: \n\n", predictions)
print("\n")

# sns.scatterplot(x=X, y=X_)
plt.show()
